# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# ...
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached click-8.3.3-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# ...
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 MB 45.0 MB/s  0:00:01 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 942.4/942.4 kB 29.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 38.5 MB/s  0:00:00
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# ...
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# ...

# %% [markdown]
# # Get Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Blf1kH1ICB0fNTqN7cfA")
project = rf.workspace("francisco-qlijv").project("soccer-players-xy9vk-bjnnb")
version = project.version(1)
dataset = version.download("yolov9")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to soccer-players-1 in yolov9:: 100%|██████████| 11527/11527 [00:02<00:00, 4762.28it/s]

# %%
dataset.location
# Out:
# '/Users/yohandeshpande/Desktop/statsapp/training/soccer-players-1'

# %%
import shutil

shutil.move('soccer-players-1/train', 'soccer-players-1/soccer-players-1/train')

shutil.move('soccer-players-1/test', 'soccer-players-1/soccer-players-1/test')

shutil.move('soccer-players-1/valid', 'soccer-players-1/soccer-players-1/valid')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/shutil.py:918, in move(src, dst, copy_function)
#     917 try:
# --> 918     os.rename(src, real_dst)
#     919 except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'soccer-players-1/train' -> 'soccer-players-1/soccer-players-1/train/train'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 import shutil
#       2
# ----> 3 shutil.move('soccer-players-1/train', 'soccer-players-1/soccer-players-1/train')
#       4
#       5 shutil.move('soccer-players-1/test', 'soccer-players-1/soccer-players-1/test')
#       6
#
# ...

# %% [markdown]
# # Training

# %%
yolo task=detect mode=train model=yolov9.pt data={dataset.location}/data.yaml epoch=100 imgsz=640
